# %% [markdown]
# ## 1. READ FILE & processing data

# %%
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import StandardScaler
import seaborn as sns
import random
import matplotlib.pyplot as plt
import numpy as np
import re
import warnings
df = pd.read_csv('https://raw.githubusercontent.com/HCMUS-KHDL-K30/KR/main/house_data.csv')
# df = df.drop(['floor_detail'], axis=1)
df.head()
# Out:
#      SalePrice             location_street  \
# 0   3044.00000                Đường Lê Lai
# 1  68031.84000          Đường Lê Trọng Tấn
# 2  22160.06100  Đường Lô C Cư Xá Phú Lâm D
# 3  42668.84440             Đường Bạch Đằng
# 4  35430.20544         Đường Phạm Văn Bạch
#
#                         location_ward location_district  number_of_toilet  \
# 0             Phường Bến Thành Quận 1            Quận 1                54
# 1  Phường Bình Hưng Hòa Quận Bình Tân     Quận Bình Tân                 9
# 2                    Phường 10 Quận 6            Quận 6                21
# 3           Phường 15 Quận Bình Thạnh   Quận Bình Thạnh                 8
# 4             Phường 15 Quận Tân Bình     Quận Tân Bình                12
#
#    access_to_school  access_to_hospital  access_to_market  number_of_floor  \
# 0                 1                   1                 1             11.5
# 1                 1                   1                 1              8.0
# 2                 0                   0                 0              8.0
# 3                 0                   0                 1              7.5
# 4                 1                   1                 1              7.5
#
#    is_having_basement  is_having_attic_floor  is_having_rooftop  alley_width  \
# 0                   0                      0                  1         15.0
# 1                   0                      0                  1         20.0
# 2                   0                      0                  0         10.0
# 3                   0                      0                  1         15.0
# 4                   1                      0                  0         30.0
#
#    number_of_bedroom    loc_lat    loc_long  total_sqft
# 0                 54  10.770076  106.694042       1.522
# 1                  8  10.813788  106.606332    2219.300
# 2                 21  10.737073  106.626365     787.500
# 3                  7  10.796401  106.700330     656.700
# 4                 12  10.829271  106.641590    1062.600

# %% [markdown]
# ## 1.1 Get info data

# %%
# review data
print(df.info)
# Out:
# <bound method DataFrame.info of          SalePrice             location_street  \
# 0       3044.00000                Đường Lê Lai
# 1      68031.84000          Đường Lê Trọng Tấn
# 2      22160.06100  Đường Lô C Cư Xá Phú Lâm D
# 3      42668.84440             Đường Bạch Đằng
# 4      35430.20544         Đường Phạm Văn Bạch
# ...            ...                         ...
# 27703   5083.12896         Đường Hoàng Hữu Nam
# 27704   1430.52930         Đường Bùi Minh Trực
# 27705   3025.52250                Đường Lê Lợi
# 27706   1392.99564         Đường Phạm Thế Hiển
# 27707   1622.57565      Đường Nguyễn Tất Thành
#
#                             location_ward location_district  number_of_toilet  \
# 0                 Phường Bến Thành Quận 1            Quận 1                54
# 1      Phường Bình Hưng Hòa Quận Bình Tân     Quận Bình Tân                 9
# 2                        Phường 10 Quận 6            Quận 6                21
# 3               Phường 15 Quận Bình Thạnh   Quận Bình Thạnh                 8
# 4                 Phường 15 Quận Tân Bình     Quận Tân Bình                12
# ...                                   ...               ...               ...
# 27703         Phường Long Thạnh Mỹ Quận 9            Quận 9                 1
# 27704                     Phường 5 Quận 8            Quận 8                 1
# 27705                Phường 4 Quận Gò Vấp       Quận Gò Vấp                 4
# 27706                     Phường 7 Quận 8            Quận 8                 1
# 27707                    Phường 18 Quận 4            Quận 4                 1
#
#        access_to_school  access_to_hospital  access_to_market  \
# 0                     1                   1                 1
# 1                     1                   1                 1
# 2                     0                   0                 0
# 3                     0                   0                 1
# 4                     1                   1                 1
# ...                 ...                 ...               ...
# 27703                 1                   1                 1
# 27704                 1                   0                 1
# 27705                 1                   0                 1
# 27706                 1                   0                 1
# 27707                 1                   0                 1
#
#        number_of_floor  is_having_basement  is_having_attic_floor  \
# 0                 11.5                   0                      0
# 1                  8.0                   0                      0
# 2                  8.0                   0                      0
# 3                  7.5                   0                      0
# 4                  7.5                   1                      0
# ...                ...                 ...                    ...
# 27703              1.0                   0                      0
# 27704              1.0                   0                      0
# 27705              1.0                   0                      0
# 27706              1.0                   0                      0
# 27707              1.0                   0                      0
#
#        is_having_rooftop  alley_width  number_of_bedroom    loc_lat  \
# 0                      1         15.0                 54  10.770076
# 1                      1         20.0                  8  10.813788
# 2                      0         10.0                 21  10.737073
# 3                      1         15.0                  7  10.796401
# 4                      0         30.0                 12  10.829271
# ...                  ...          ...                ...        ...
# 27703                  0         12.0                  1  10.858170
# 27704                  0          1.0                  1  10.738651
# 27705                  0          4.5                  4  10.822450
# 27706                  0          4.0                  1  10.707215
# 27707                  0          3.0                  3  10.759876
#
#          loc_long  total_sqft
# 0      106.694042       1.522
# 1      106.606332    2219.300
# 2      106.626365     787.500
# 3      106.700330     656.700
# 4      106.641590    1062.600
# ...           ...         ...
# 27703  106.813547      31.900
# 27704  106.659205      29.300
# 27705  106.685568      45.000
# 27706  106.623262      36.600
# 27707  106.712924      65.500
#
# [27708 rows x 17 columns]>

# %% [markdown]
# ## 1.2 Prepare data

# %% [markdown]
# Change data type to code

# %%
df = df[df['number_of_bedroom'] <= 10]
df = df[df['number_of_toilet'] <= 10]
df = df[df['alley_width'] <= 15]

# review data after filter
print(df.head())
print(df.describe())
# Out:
#      SalePrice      location_street              location_ward  \
# 3   42668.8444      Đường Bạch Đằng  Phường 15 Quận Bình Thạnh
# 10  26521.7400           Đường Số 2            Phường 4 Quận 3
# 11   4493.7600          Đường Số 59      Phường 14 Quận Gò Vấp
# 12  24916.3560  Đường Điện Biên Phủ  Phường 17 Quận Bình Thạnh
# 21  10776.4200  Đường Tô Hiến Thành          Phường 13 Quận 10
#
#    location_district  number_of_toilet  access_to_school  access_to_hospital  \
# 3    Quận Bình Thạnh                 8                 0                   0
# 10            Quận 3                 6                 1                   1
# 11       Quận Gò Vấp                 6                 1                   0
# 12   Quận Bình Thạnh                 2                 0                   0
# 21           Quận 10                 6                 0                   0
#
#     access_to_market  number_of_floor  is_having_basement  \
# 3                  1              7.5                   0
# 10                 1              7.0                   0
# 11                 0              7.0                   0
# 12                 1              7.0                   0
# 21                 0              6.5                   0
#
#     is_having_attic_floor  is_having_rooftop  alley_width  number_of_bedroom  \
# 3                       0                  1        15.00                  7
# 10                      0                  0         8.00                  6
# 11                      0                  0         5.00                 10
# 12                      0                  0         8.19                  3
# 21                      0                  0         3.00                  5
#
#       loc_lat    loc_long  total_sqft
# 3   10.796401  106.700330       656.7
# 10  10.773210  106.681914       219.0
# 11  10.843037  106.637165        30.2
# 12  10.801243  106.710983       115.8
# 21  10.778093  106.665834       176.4
#           SalePrice  number_of_toilet  access_to_school  access_to_hospital  \
# count  26271.000000      26271.000000      26271.000000        26271.000000
# mean    6532.253343          2.781698          0.720833            0.211336
# std     5573.147946          1.622114          0.448598            0.408264
# min      329.940000          1.000000          0.000000            0.000000
# 25%     3402.991905          2.000000          0.000000            0.000000
# 50%     4958.194050          2.000000          1.000000            0.000000
# 75%     7551.192000          4.000000          1.000000            0.000000
# max    91304.426400         10.000000          1.000000            1.000000
#
#        access_to_market  number_of_floor  is_having_basement  \
# count      26271.000000     26271.000000        26271.000000
# mean           0.779795         2.419988            0.002588
# std            0.414393         0.894976            0.050811
# min            0.000000         1.000000            0.000000
# 25%            1.000000         2.000000            0.000000
# 50%            1.000000         2.000000            0.000000
# 75%            1.000000         3.000000            0.000000
# max            1.000000         7.500000            1.000000
#
#        is_having_attic_floor  is_having_rooftop   alley_width  \
# count           26271.000000       26271.000000  26271.000000
# mean                0.014388           0.225915      5.053065
# std                 0.119088           0.418191      3.123815
# min                 0.000000           0.000000      0.500000
# 25%                 0.000000           0.000000      3.000000
# 50%                 0.000000           0.000000      4.000000
# 75%                 0.000000           0.000000      6.000000
# max                 1.000000           1.000000     15.000000
#
#        number_of_bedroom       loc_lat      loc_long    total_sqft
# count       26271.000000  26271.000000  26271.000000  26271.000000
# mean            3.031860     10.795597    106.669881    119.342777
# std             1.577998      0.048402      0.050042     82.422341
# min             1.000000     10.617409    106.480977      1.000000
# 25%             2.000000     10.759784    106.634188     62.400000
# 50%             3.000000     10.793382    106.664118     98.100000
# 75%             4.000000     10.835689    106.697974    156.600000
# max            10.000000     10.914522    106.859596   1584.300000

# %% [markdown]
# ## Caculated distance

# %%
print(df.head(12))
# Out:
#       SalePrice       location_street                         location_ward  \
# 3   42668.84440       Đường Bạch Đằng             Phường 15 Quận Bình Thạnh
# 10  26521.74000            Đường Số 2                       Phường 4 Quận 3
# 11   4493.76000           Đường Số 59                 Phường 14 Quận Gò Vấp
# 12  24916.35600   Đường Điện Biên Phủ             Phường 17 Quận Bình Thạnh
# 21  10776.42000   Đường Tô Hiến Thành                     Phường 13 Quận 10
# 25  27916.29600  Đường Nguyễn Văn Đậu             Phường 11 Quận Bình Thạnh
# 26   8395.15600       Đường Tân Lập 2                Phường Hiệp Phú Quận 9
# 27  39396.32000      Đường Võ Văn Tần                       Phường 6 Quận 3
# 28  17874.24000  Đường Trần Hữu Trang              Phường 11 Quận Phú Nhuận
# 31  13046.93376   Đường Lê Hồng Phong                      Phường 1 Quận 10
# 32  13286.00000       Đường Đồng Xoài               Phường 13 Quận Tân Bình
# 36  37584.00000           Đường Số 1A  Phường Bình Trị Đông B Quận Bình Tân
#
#    location_district  number_of_toilet  access_to_school  access_to_hospital  \
# 3    Quận Bình Thạnh                 8                 0                   0
# 10            Quận 3                 6                 1                   1
# 11       Quận Gò Vấp                 6                 1                   0
# 12   Quận Bình Thạnh                 2                 0                   0
# 21           Quận 10                 6                 0                   0
# 25   Quận Bình Thạnh                10                 1                   0
# 26            Quận 9                 9                 1                   0
# 27            Quận 3                 6                 0                   0
# 28    Quận Phú Nhuận                 7                 0                   1
# 31           Quận 10                 3                 0                   0
# 32     Quận Tân Bình                 6                 1                   0
# 36     Quận Bình Tân                10                 1                   1
#
#     access_to_market  number_of_floor  is_having_basement  \
# 3                  1              7.5                   0
# 10                 1              7.0                   0
# 11                 0              7.0                   0
# 12                 1              7.0                   0
# 21                 0              6.5                   0
# 25                 1              6.5                   0
# 26                 1              6.5                   0
# 27                 0              6.5                   1
# 28                 1              6.5                   0
# 31                 0              6.5                   0
# 32                 1              6.5                   0
# 36                 1              6.0                   0
#
#     is_having_attic_floor  is_having_rooftop  alley_width  number_of_bedroom  \
# 3                       0                  1        15.00                  7
# 10                      0                  0         8.00                  6
# 11                      0                  0         5.00                 10
# 12                      0                  0         8.19                  3
# 21                      0                  0         3.00                  5
# 25                      0                  0         7.00                  9
# 26                      0                  1        10.00                  9
# 27                      0                  0        12.00                  6
# 28                      0                  0         4.00                  6
# 31                      0                  0         6.50                  4
# 32                      0                  0         6.00                  6
# 36                      0                  0        14.00                 10
#
#       loc_lat    loc_long  total_sqft
# 3   10.796401  106.700330       656.7
# 10  10.773210  106.681914       219.0
# 11  10.843037  106.637165        30.2
# 12  10.801243  106.710983       115.8
# 21  10.778093  106.665834       176.4
# 25  10.812344  106.693096       420.8
# 26  10.846762  106.778404       368.4
# 27  10.750103  106.646448       537.5
# 28  10.791863  106.676160       328.6
# 31  10.764162  106.675769       148.0
# 32  10.800510  106.646268       357.0
# 36  10.747956  106.613701       539.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26271 entries, 3 to 27707
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SalePrice              26271 non-null  float64
#  1   location_street        26271 non-null  object
#  2   location_ward          26271 non-null  object
#  3   location_district      26271 non-null  object
#  4   number_of_toilet       26271 non-null  int64
#  5   access_to_school       26271 non-null  int64
#  6   access_to_hospital     26271 non-null  int64
#  7   access_to_market       26271 non-null  int64
#  8   number_of_floor        26271 non-null  float64
#  9   is_having_basement     26271 non-null  int64
#  10  is_having_attic_floor  26271 non-null  int64
#  11  is_having_rooftop      26271 non-null  int64
#  12  alley_width            26271 non-null  float64
#  13  number_of_bedroom      26271 non-null  int64
#  14  loc_lat                26271 non-null  float64
#  15  loc_long               26271 non-null  float64
#  16  total_sqft             26271 non-null  float64
# dtypes: float64(6), int64(8), object(3)
# memory usage: 3.6+ MB

# %%
df['location_ward'].value_counts()
# Out:
# Phường Hiệp Thành Quận 12               505
# Phường Bình Hưng Hòa A Quận Bình Tân    467
# Thị trấn Nhà Bè Huyện Nhà Bè            392
# Phường Bình Trị Đông A Quận Bình Tân    386
# Phường Bình Trị Đông Quận Bình Tân      381
#                                        ...
# Phường 8 Quận 5                           2
# Phường Bình Khánh Quận 2                  2
# khu Hà Đô Phường 12                       1
# Xã Bình Lợi Huyện Bình Chánh              1
# Phường An Khánh Quận 2                    1
# Name: location_ward, Length: 293, dtype: int64

# %%
from collections import Counter
import math

def knn(data, query, k, distance_fn, choice_fn):
    neighbor_distances_and_indices = []
    
    # 3. For each example in the data
    for index, example in enumerate(data):
        # 3.1 Calculate the distance between the query example and the current
        # example from the data.
        distance = distance_fn(example[:-1], query)
        
        # 3.2 Add the distance and the index of the example to an ordered collection
        neighbor_distances_and_indices.append((distance, index))
    
    # 4. Sort the ordered collection of distances and indices from
    # smallest to largest (in ascending order) by the distances
    sorted_neighbor_distances_and_indices = sorted(neighbor_distances_and_indices)
    
    # 5. Pick the first K entries from the sorted collection
    k_nearest_distances_and_indices = sorted_neighbor_distances_and_indices[:k]
    
    # 6. Get the labels of the selected K entries
    k_nearest_labels = [data[i][-1] for distance, i in k_nearest_distances_and_indices]

    # 7. If regression (choice_fn = mean), return the average of the K labels
    # 8. If classification (choice_fn = mode), return the mode of the K labels
    return k_nearest_distances_and_indices , choice_fn(k_nearest_labels)

def mean(labels):
    return sum(labels) / len(labels)

def mode(labels):
    return Counter(labels).most_common(1)[0][0]

def euclidean_distance(point1, point2):
    sum_squared_distance = 0
    for i in range(len(point1)):
        sum_squared_distance += math.pow((point1[i] - point2[i]), 2)
    return math.sqrt(sum_squared_distance)

# %%
from geopy import distance
lat_long = df['loc_lat'].astype(str) + ',' + df['loc_long'].astype(str)
lat_long = list(map(eval, lat_long))
home_predict = (10.7780926, 106.6658339)
kilometers = []
for i in lat_long:
    kilometers.append(round(distance.distance(i, home_predict).km, 2))
df['dist2home_i'] = kilometers
df['dist2home_i*1000'] = df['dist2home_i']*1000

# %%
# from geopy import distance
# lat_long = df['loc_lat'].astype(str) + ',' + df['loc_long'].astype(str)
# lat_long = list(map(eval, lat_long))
# home_predict = (lat_GT, long_GT)
# kilometers = []
# for i in lat_long:
#     kilometers.append(round(distance.distance(i, home_predict).km*1000, 2))
# df['dist2home_i*1000'] = kilometers

# %%
# raw_houses_data = []

raw_houses_data = df.values.tolist()

houses_recommendation_data = []
for row in raw_houses_data:
    data_row = list(map(float, row[:][16:]))
    houses_recommendation_data.append(data_row)
houses_recommendation_data
# Out:
# [[656.7, 4.28, 4280.0],
#  [219.0, 1.84, 1840.0],
#  [30.2, 7.84, 7840.0],
#  [115.8, 5.56, 5560.0],
#  [176.4, 0.0, 0.0],
#  [420.8, 4.82, 4820.0],
#  [368.4, 14.47, 14470.0],
#  [537.5, 3.75, 3750.0],
#  [328.6, 1.9, 1900.0],
#  [148.0, 1.89, 1890.0],
#  [357.0, 3.28, 3280.0],
#  [539.3, 6.6, 6600.0],
#  [747.6, 6.48, 6480.0],
#  [393.8, 4.54, 4540.0],
#  [276.0, 0.81, 810.0],
#  [106.3, 0.49, 490.0],
#  [586.0, 9.87, 9870.0],
#  [422.4, 1.87, 1870.0],
#  [989.2, 1.98, 1980.0],
#  [500.4, 8.41, 8410.0],
#  [939.7, 3.8, 3800.0],
#  [232.3, 1.69, 1690.0],
#  [431.6, 5.16, 5160.0],
#  [147.7, 1.38, 1380.0],
#  [491.8, 1.55, 1550.0],
#  [220.8, 7.68, 7680.0],
#  [200.0, 3.37, 3370.0],
#  [255.5, 8.41, 8410.0],
#  [305.5, 8.41, 8410.0],
#  [320.0, 9.75, 9750.0],
#  [247.4, 9.75, 9750.0],
#  ...]

# %%
# from knn_from_scratch import knn, euclidean_distance

def recommend_houses(house_query, k_recommendations):
    raw_houses_data = df.values.tolist()

    # Prepare the data for use in the knn algorithm by picking
    # the relevant columns and converting the numeric columns
    # to numbers since they were read in as strings
#     houses_recommendation_data = []
#     for row in raw_houses_data:
#         data_row = list(map(float, row[:][16:]))
#         houses_recommendation_data.append(data_row)
    houses_recommendation_data = []
    for row in raw_houses_data:
        data_row = list(map(float, row[:][16:]))
        houses_recommendation_data.append(data_row)

    # Use the KNN algorithm to get the 3 houses that are most
    # similar to the_predict.
    recommendation_indices, _ = knn(
        houses_recommendation_data, house_query, k=k_recommendations,
        distance_fn=euclidean_distance, choice_fn=lambda x: None
    )

    house_recommendations = []
    for _, index in recommendation_indices:
        house_recommendations.append(raw_houses_data[index])

    return house_recommendations

if __name__ == '__main__':
    the_predict = [150.3, 0.0, 0.0] # feature vector for The Predict
    recommended_houses = recommend_houses(house_query=the_predict, k_recommendations=3)

    # Print recommended house
    for recommendation in recommended_houses:
        print(recommendation)
# Out:
# [7813.12, 'Cách Mạng Tháng Tám', 'Phường 15 Quận 10', 'Quận 10', 5, 0, 0, 0, 3.0, 0, 0, 0, 4.0, 5, 10.78125455, 106.6652255, 150.0, 0.36, 360.0]
# [9527.84, 'Đường Cách Mạng Tháng Tám', 'Phường 11 Quận 3', 'Quận 3', 3, 0, 0, 0, 2.0, 0, 0, 0, 4.5, 4, 10.7834318, 106.6711445, 150.0, 0.83, 830.0]
# [7513.11624, 'Đường Lê Hồng Phong', 'Phường 10 Quận 10', 'Quận 10', 2, 0, 0, 0, 2.0, 0, 0, 0, 3.5, 4, 10.7708552, 106.6730741, 150.4, 1.13, 1130.0]

# %% [markdown]
# ## 2. FEATURE SELECTION & DATA SPLIT

# %%
## 3. FEATURE SELECTION & DATA SPLIT
# # list feature

# features = ['location_street_code', 'location_ward_code', 'location_district_code', 'location_city_code',
#             'number_of_bedroom', 'number_of_toilet', 'access_to_school', 'access_to_hospital', 'access_to_market', 
#             'number_of_floor', 'is_having_basement', 'is_having_attic_floor',
#             'is_having_rooftop', 'alley_width', 'status_house_code', 'length','width', 'view_code', 'distance','Legal_documents_code']

features = ['number_of_bedroom', 'number_of_toilet', 'access_to_school', 'access_to_hospital', 'access_to_market', 
            'number_of_floor','alley_width', 'total_sqft','distance']

# %%
# Transfrom data 
# df['SalePrice'] = np.log1p(df['SalePrice'])
# df['total_sqft'] = np.log1p(df['total_sqft'])

# %%
y = df['SalePrice']
y.describe()

# %%
#importing the necessary libraries
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# forward_selection
def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

forward_selection(X,y)

# %%
def backward_elimination(data, target,significance_level = 0.05):
    features = data.columns.tolist()
    while(len(features)>0):
        features_with_constant = sm.add_constant(data[features])
        p_values = sm.OLS(target, features_with_constant).fit().pvalues[1:]
        max_p_value = p_values.max()
        if(max_p_value >= significance_level):
            excluded_feature = p_values.idxmax()
            features.remove(excluded_feature)
        else:
            break 
    return features

backward_elimination(X,y)

# %%
def stepwise_selection(data, target,SL_in=0.05,SL_out = 0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<SL_in):
            best_features.append(new_pval.idxmin())
            while(len(best_features)>0):
                best_features_with_constant = sm.add_constant(data[best_features])
                p_values = sm.OLS(target, best_features_with_constant).fit().pvalues[1:]
                max_p_value = p_values.max()
                if(max_p_value >= SL_out):
                    excluded_feature = p_values.idxmax()
                    best_features.remove(excluded_feature)
                else:
                    break 
        else:
            break
    return best_features

stepwise_selection(X,y)

# %%
best_features = ['total_sqft',
 'alley_width',
 'distance',
 'access_to_school', 
 'access_to_hospital']

# ['is_having_rooftop',
#  'width',
#  'number_of_toilet',
#  'length',
#  'location_ward_code',
#  'alley_width',
#  'number_of_floor',
#  'distance',
#  'location_district_code',
#  'access_to_school',
#  'number_of_bedroom',
#  'is_having_basement',
#  'is_having_attic_floor',
#  'access_to_hospital',
#  'access_to_market',
#  'view_code']

# ['total_sqft',
#  'alley_width',
#  'distance',
#  'number_of_bedroom',
#  'number_of_floor',
#  'access_to_school',
#  'number_of_toilet', 
#  'access_to_hospital',
#  'access_to_market']

# %%
import seaborn as sb
sb.heatmap(df[best_features].corr(), annot=True, cmap='magma')

# %%
import seaborn as sns
#histogram of Sale price distribution
sns.distplot(df['SalePrice'])

# %%
from scipy.stats import skew
#Top skewed columns

skewed_features = df[best_features].apply(lambda x: skew(x)).sort_values(ascending=False)
high_skew = skewed_features[abs(skewed_features) > 1]
print(high_skew)

# %%
# #Transforming skewed columns
# for feature in high_skew.index:
#     df[feature] = np.log1p(df[feature])

# %%
from termcolor import colored as cl 
from sklearn.metrics import explained_variance_score as evs  # evaluation metric
from sklearn.metrics import r2_score as r2  # evaluation metric
from sklearn.model_selection import train_test_split 
# Split train & test dataset
X_var = df[best_features].values
y_var = df['SalePrice'].values
X_train, X_test, y_train, y_test = train_test_split(X_var, y_var, test_size=0.2, random_state=0)

# %%
# 4.1. OLS

ols = LinearRegression()
results = ols.fit(X_train, y_train)
ols_yhat = ols.predict(X_test)


# 2. R-squared
print(cl('R-SQUARED:', attrs = ['bold']))
print('-------------------------------------------------------------------------------')
print(cl('R-Squared of OLS model is {}'.format(r2(y_test, ols_yhat)), attrs = ['bold']))
print('-------------------------------------------------------------------------------')

# %%
import statsmodels.api as sm

model = sm.OLS(y_train, X_train)
results = model.fit()
print(results.summary())

# %%
import statsmodels.api as sm

model = sm.OLS(y_var, X_var)
results = model.fit()
print(results.summary())

# %%
print(results.params)

# %%
s1 = pd.Series(best_features)
s2 = pd.Series(results.params)
s3 = pd.concat([s1, s2], axis =1)
s3

# %% [markdown]
# ## Model
# Log(SalePrice) = 1.850679*Log(total_sqft) + 0.005466 *alley_width - 0.026513 *distance + 0.164837*access_to_school + 0.054710 * access_to_hospital
